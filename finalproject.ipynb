# %% [markdown]
# # <p style="background-color:red; font-family:Book Antiqua ; font-size:250%; text-align:center; border-radius: 15px 50px;">Spotify & Youtube | EDA Project🎙🎛🎧 📉📊</p>

# %% [markdown]
# #### Columns Explanations
# It includes 26 variables for each of the songs collected from spotify. These variables are briefly described next:
#
# **Track :**
# name of the song, as visible on the Spotify platform.
#
# **Artist:**
# name of the artist.
#
# **Url_spotify:**
# the Url of the artist.
#
# **Album:**
# the album in wich the song is contained on Spotify.
#
# **Album_type:**
# indicates if the song is relesead on Spotify as a single or contained in an album.
#
# **Uri:**
# a spotify link used to find the song through the API.
#
# **Danceability:**
# describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **Energy:**
# is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **Key:**
# the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
# **Loudness:**
# the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# **Speechiness:**
# detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **Acousticness:**
# a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# **Instrumentalness:**
# predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# **Liveness:**
# detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# **Valence:**
# a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **Tempo:**
# the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# **Duration_ms:**
# the duration of the track in milliseconds.
#
# **Stream:**
# number of streams of the song on Spotify.
#
# **Url_youtube:**
# url of the video linked to the song on Youtube, if it have any.
#
# **Title:**
# title of the videoclip on youtube.
#
# **Channel:**
# name of the channel that have published the video.
#
# **Views:**
# number of views.
#
# **Likes:**
# number of likes.
#
# **Comments:**
# number of comments.
#
# **Description:**
# description of the video on Youtube.
#
# **Licensed:**
# Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.
#
# **official_video:**
# boolean value that indicates if the video found is the official video of the song.

# %% [markdown]
# ![Youtube-logo.jpg](attachment:Youtube-logo.jpg)

# %% [markdown]
# ![Spotify_logo_with_text.svg.png](attachment:Spotify_logo_with_text.svg.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/LENOVO/Desktop/Kodlasam ders notları/Capstone Proje/Capstone Project EDA DataSet/Spotify_Youtube.csv")
data
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
data.shape
# Out:
# (20718, 28)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
data.transpose()
# Out:
#                                                               0      \
# Unnamed: 0                                                        0
# Artist                                                     Gorillaz
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...
# Track                                                Feel Good Inc.
# Album                                                    Demon Days
# Album_type                                                    album
# Uri                            spotify:track:0d28khcov6AiegSCpG5TuT
# Danceability                                                  0.818
# Energy                                                        0.705
# Key                                                             6.0
# Loudness                                                     -6.679
# Speechiness                                                   0.177
# Acousticness                                                0.00836
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# Remove any leading or trailing spaces from column names
data.columns = data.columns.str.strip()

# %%
duplicate_rows_check = data[data.duplicated(subset=['Uri', 'Url_spotify', 'Url_youtube'], keep=False)]

duplicate_rows_check
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Artist, Url_spotify, Track, Album, Album_type, Uri, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_ms, Url_youtube, Title, Channel, Views, Likes, Comments, Description, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 28 columns]

# %%
data.drop(['Unnamed: 0','Url_spotify', 'Uri', 'Url_youtube', 'Title', 'Description'],axis = 1,inplace=True)
data
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
# Ensure the columns are of string type
data['official_video'] = data['official_video'].astype(str)
data['Licensed'] = data['Licensed'].astype(str)

# Replace 'True' with 'Yes' and 'False' with 'No'
data['official_video'] = data['official_video'].str.replace('True', 'Yes')
data['official_video'] = data['official_video'].str.replace('False', 'No')
data['Licensed'] = data['Licensed'].str.replace('True', 'Yes')
data['Licensed'] = data['Licensed'].str.replace('False', 'No')

# Display the columns
data[['official_video', 'Licensed']]
# Out:
#       official_video Licensed
# 0                Yes      Yes
# 1                Yes      Yes
# 2                Yes      Yes
# 3                Yes      Yes
# 4                Yes      Yes
# ...              ...      ...
# 20713            Yes      Yes
# 20714            Yes      Yes
# 20715            Yes      Yes
# 20716            Yes      Yes
# 20717            Yes      Yes
#
# [20718 rows x 2 columns]

# %% [markdown]
# #### We can change astype to boolean instead of renaming the values for Licensed and official_video columns like below
# ##### data['Licensed']= data['Licensed'].astype('bool')
# ###### data['official_video']= data['official_video'].astype('bool')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Track             20718 non-null  object
#  2   Album             20718 non-null  object
#  3   Album_type        20718 non-null  object
#  4   Danceability      20716 non-null  float64
#  5   Energy            20716 non-null  float64
#  6   Key               20716 non-null  float64
#  7   Loudness          20716 non-null  float64
#  8   Speechiness       20716 non-null  float64
#  9   Acousticness      20716 non-null  float64
#  10  Instrumentalness  20716 non-null  float64
#  11  Liveness          20716 non-null  float64
#  12  Valence           20716 non-null  float64
#  13  Tempo             20716 non-null  float64
#  14  Duration_ms       20716 non-null  float64
#  15  Channel           20248 non-null  object
# ...

# %%
# transform ms to minute
data["Duration_minutes"] = data["Duration_ms"] // 60000

# transform remaining ms to seconds
data["Duration_seconds"] = (data["Duration_ms"] % 60000) / 1000

# %%
# set NaN values to zero
data["Duration_minutes"].fillna(0, inplace=True)
data["Duration_seconds"].fillna(0, inplace=True)

data["Duration"] = data["Duration_minutes"].astype(int).astype(str) + ":" + data["Duration_seconds"].apply(lambda x: f"{x:05.2f}")

# %%
# check the code

data.sort_values(by="Duration", ascending=False).head(5)
# Out:
#                        Artist  \
# 6798      Sergei Rachmaninoff
# 13761       Elevation Worship
# 15592  White Noise Baby Sleep
# 15589  White Noise Baby Sleep
# 6019                   Gojira
#
#                                                    Track  \
# 6798   Piano Concerto No. 2 in C Minor, Op. 18: I. Mo...
# 13761         Jireh (feat. Chandler Moore & Naomi Raine)
# 15592  Perfect Natural White Noise as a Relaxing Ambi...
# 15589  White Noise Sleeping Aid to Help My Baby Fall ...
# 6019                                    The art of dying
#
#                                                    Album Album_type  \
# 6798   Rachmaninoff: Piano Concerto No. 2 in C Minor,...      album
# 13761                                Old Church Basement      album
# 15592                    White Noise for Sleeping Babies      album
# 15589                    White Noise for Sleeping Babies      album
# 6019                                The way of all flesh      album
#
# ...

# %% [markdown]
# #### we changed ms to minutes and created a new column as duration.we kept the Duration_ms and Duration_seconds columns in our dataframe incase we might need.

# %% [markdown]
# # Correlation

# %%
numeric_columns = data.select_dtypes(include=['float64'])
numeric_columns.describe().T
# Out:
#                     count          mean           std           min  \
# Danceability      20716.0  6.197775e-01  1.652724e-01      0.000000
# Energy            20716.0  6.352503e-01  2.141468e-01      0.000020
# Key               20716.0  5.300348e+00  3.576449e+00      0.000000
# Loudness          20716.0 -7.671680e+00  4.632749e+00    -46.251000
# Speechiness       20716.0  9.645601e-02  1.119600e-01      0.000000
# Acousticness      20716.0  2.915353e-01  2.862988e-01      0.000001
# Instrumentalness  20716.0  5.596156e-02  1.932620e-01      0.000000
# Liveness          20716.0  1.935210e-01  1.685309e-01      0.014500
# Valence           20716.0  5.298533e-01  2.454408e-01      0.000000
# Tempo             20716.0  1.206383e+02  2.957902e+01      0.000000
# Duration_ms       20716.0  2.247176e+05  1.247905e+05  30985.000000
# Views             20248.0  9.393782e+07  2.746443e+08      0.000000
# Likes             20177.0  6.633411e+05  1.789324e+06      0.000000
# ...

# %%
data.corr(numeric_only=True)
# Out:
#                   Danceability    Energy       Key  Loudness  Speechiness  \
# Danceability          1.000000  0.236596  0.037735  0.353408     0.210376
# Energy                0.236596  1.000000  0.030160  0.744845     0.065319
# Key                   0.037735  0.030160  1.000000  0.025266     0.019778
# Loudness              0.353408  0.744845  0.025266  1.000000     0.033699
# Speechiness           0.210376  0.065319  0.019778  0.033699     1.000000
# Acousticness         -0.279435 -0.658304 -0.030818 -0.547680    -0.077598
# Instrumentalness     -0.318611 -0.310058  0.000747 -0.545406    -0.109895
# Liveness             -0.084482  0.173717 -0.011008  0.087062     0.085463
# Valence               0.465756  0.389158  0.042559  0.311578     0.059204
# Tempo                -0.065943  0.157383  0.001855  0.144766     0.037553
# Duration_ms          -0.089159  0.022660  0.003186  0.012063    -0.051248
# Views                 0.088546  0.067575  0.007767  0.119244    -0.013240
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=.5, annot_kws={"size": 7})
plt.title('Correlation Heatmap');

# %% [markdown]
# # EDA

# %%
album_type_counts = data['Album_type'].value_counts()

# Plotting the pie chart

album_type_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Songs by Album Type')
plt.tight_layout()
plt.show()

# %%
# Set the font scale
sns.set(font_scale=0.8)

# Create separate subplots for each countplot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))  # Adjusted figsize for better visibility

# Plot countplot for 'Licensed'
sns.countplot(x=data['Licensed'], ax=axes[0], palette='pastel')
axes[0].set_title('Count of Licensed')
axes[0].set_xlabel('Licensed')
axes[0].set_ylabel('Count')

# Plot countplot for 'official_video'
sns.countplot(x=data['official_video'], ax=axes[1], palette='viridis')
axes[1].set_title('Count of Official Video')
axes[1].set_xlabel('Official Video')
axes[1].set_ylabel('Count');

# %%
top10_viewed=data.sort_values(by='Views',ascending=False).head(10)

# %%
plt.figure(figsize=(12, 6))
plt.title("Top 10 Songs with their Artist on Youtube")
sns.barplot(y='Track', x='Views', hue='Artist', data=top10_viewed, orient='h')
plt.xlabel('Views')
plt.legend(title='Artist')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
top10_streamed=data.sort_values(by='Stream',ascending=False).head(10)

# %%
plt.figure(figsize=(12, 6))
plt.title("Top 10 Songs with their Artist on Spotify")
sns.barplot(y='Track', x='Stream', hue='Artist', data=top10_streamed, orient='h')
plt.xlabel('Views')
plt.legend(title='Artist')
plt.show()

# %%
# Set the font scale
sns.set(font_scale=0.8)

# Create a figure and subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 15))

# Features to plot
features = ["Danceability", "Energy", "Key", "Loudness",
            "Speechiness", "Acousticness", "Instrumentalness", "Liveness",
            "Valence", "Tempo"]

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate over each feature and create a horizontal bar plot for each track
for idx, feature in enumerate(features):
    if idx < len(axes):  # Ensure we don't exceed the number of available subplots
        sns.barplot(y='Track', x=feature, data=top10_viewed, ax=axes[idx], palette="viridis", orient='h')
        axes[idx].set_title(f'{feature.replace("_", " ").title()}', fontsize=15)  # Set title font size
        axes[idx].set_xlabel(feature, fontsize=1)  # Set x-axis label font size
        axes[idx].set_ylabel('Track', fontsize=1)  # Set y-axis label font size
        
        # Adjust tick label sizes
        #axes[idx].tick_params(axis='x', labelsize=10)  # Set x-axis tick labels font size
        axes[idx].tick_params(axis='y', labelsize=15)  # Set y-axis tick labels font size
        
        # Ensure y-axis tick labels are horizontal
        axes[idx].set_yticklabels(axes[idx].get_yticklabels(), rotation=0)

# Remove unused subplots
for idx in range(len(features), len(axes)):
    fig.delaxes(axes[idx])

# Adjust layout
fig.suptitle('Attributes of Top 10 Most Viewed on Youtube', fontsize=20, y=1.05)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4436\625351824.py:36: UserWarning:
#
# Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4436\625351824.py:36: UserWarning:
#
# Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4436\625351824.py:36: UserWarning:
#
# Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4436\625351824.py:36: UserWarning:
#
# Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4436\625351824.py:36: UserWarning:
#
# Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#
# ...

# %%
# Set the font scale
sns.set(font_scale=0.8)

# Create a figure and subplots
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 15))

# Features to plot
features = ["Danceability", "Energy", "Key", "Loudness",
            "Speechiness", "Acousticness", "Instrumentalness", "Liveness",
            "Valence", "Tempo"]

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate over each feature and create a horizontal bar plot for each track
for idx, feature in enumerate(features):
    if idx < len(axes):  # Ensure we don't exceed the number of available subplots
        sns.barplot(y='Track', x=feature, data=top10_streamed, ax=axes[idx], palette="viridis", orient='h')
        axes[idx].set_title(f'{feature.replace("_", " ").title()}', fontsize=15)  # Set title font size
        axes[idx].set_xlabel(feature, fontsize=1)  # Set x-axis label font size
        axes[idx].set_ylabel('Track', fontsize=1)  # Set y-axis label font size
        
        # Adjust tick label sizes
        #axes[idx].tick_params(axis='x', labelsize=10)  # Set x-axis tick labels font size
        axes[idx].tick_params(axis='y', labelsize=15)  # Set y-axis tick labels font size
        
        # Ensure y-axis tick labels are horizontal
        axes[idx].set_yticklabels(axes[idx].get_yticklabels(), rotation=0)

# Remove unused subplots
for idx in range(len(features), len(axes)):
    fig.delaxes(axes[idx])

# Adjust layout
fig.suptitle('Attributes of Top 10 Most Streamed on Spotify', fontsize=20, y=1.05)
plt.tight_layout()
plt.show()

# %%
top10_likes = data[data['Likes'].isin(data['Likes'].sort_values(ascending=False).head(10))]
top10_comments = data[data['Comments'].isin(data['Comments'].sort_values(ascending=False).head(10))]

# %%
# Create a figure and a grid of subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Top 10 songs with most comments
top10_comments.plot(kind='barh', x='Track', y='Comments', ax=axs[0], color='lightgreen', legend=False)
axs[0].set_title('Top 10 Songs with Most Comments')
axs[0].set_xlabel('Comments')
axs[0].set_ylabel('Track')

# Top 10 songs with most likes
top10_likes.plot(kind='barh', x='Track', y='Likes', ax=axs[1], color='salmon', legend=False)
axs[1].set_title('Top 10 Songs with Most Likes')
axs[1].set_xlabel('Likes')
axs[1].set_ylabel('Track')

# Adjust layout
fig.tight_layout()

# Display the plot
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14924\1912701116.py:17: UserWarning:
#
# Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14924\1912701116.py:17: UserWarning:
#
# Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14924\1912701116.py:17: UserWarning:
#
# Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14924\1912701116.py:17: UserWarning:
#
# Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_14924\1912701116.py:17: UserWarning:
#
# Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#
# ...

# %%
# Features to plot
features = ["Danceability", "Energy", "Key", "Loudness",
            "Speechiness", "Acousticness", "Instrumentalness", "Liveness",
            "Valence", "Tempo"]

# Create a grid of scatter plots for each feature vs. Likes
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 15))
axes = axes.flatten()

for idx, feature in enumerate(features):
    sns.scatterplot(x=feature, y='Likes', data=data, hue='Album_type', ax=axes[idx])
    axes[idx].set_title(f'{feature} vs Likes',fontsize=14)
    axes[idx].set_xlabel(feature)
    axes[idx].set_ylabel('Likes')

# Remove any unused subplots
for idx in range(len(features), len(axes)):
    fig.delaxes(axes[idx])

# Add a main title for the entire figure
fig.suptitle('Likes vs Features', fontsize=20, y=1.02)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Check for NaN values and handle them
data = data.dropna(subset=['Views', 'Likes'])

# Scatter plot of Views vs. Likes
plt.figure(figsize=(10, 6))
plt.scatter(data['Views'], data['Likes'], color='skyblue', alpha=0.7, edgecolors='black')
plt.title('Relationship between Views and Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.grid(True, linestyle='--', alpha=0.7)

# Adding a trendline
try:
    z = np.polyfit(data['Views'], data['Likes'], 1)
    p = np.poly1d(z)
    plt.plot(data['Views'], p(data['Views']), "y--", label='Trendline')
    plt.legend()
except np.linalg.LinAlgError:
    print("Error in fitting the trendline.")

plt.show()

# %%
# Check for NaN values and handle them
data = data.dropna(subset=['Likes','Comments'])

# Scatter plot of Views vs. Likes
plt.figure(figsize=(10, 6))
plt.scatter(data['Likes'], data['Comments'], color='skyblue', alpha=0.7, edgecolors='black')
plt.title('Relationship between Likes and Comments')
plt.xlabel('Likes')
plt.ylabel('Comments')
plt.grid(True, linestyle='--', alpha=0.7)

# Adding a trendline
try:
    z = np.polyfit(data['Likes'], data['Comments'], 1)
    p = np.poly1d(z)
    plt.plot(data['Likes'], p(data['Likes']), "y--", label='Trendline')
    plt.legend()
except np.linalg.LinAlgError:
    print("Error in fitting the trendline.")

plt.show()

# %%
# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 12))

# Scatter plot for Stream vs Duration_ms
sns.scatterplot(x='Duration_ms', y='Stream', data=data, ax=axes[0, 0])
axes[0, 0].set_title('Stream Vs Duration')
axes[0, 0].set_xlabel('Duration_ms')
axes[0, 0].set_ylabel('Stream')

# Scatter plot for Views vs Duration_ms
sns.scatterplot(x='Duration_ms', y='Views', data=data, ax=axes[0, 1])
axes[0, 1].set_title('Views Vs Duration')
axes[0, 1].set_xlabel('Duration_ms')
axes[0, 1].set_ylabel('Views')

# Scatter plot for Likes vs Duration_ms
sns.scatterplot(x='Duration_ms', y='Likes', data=data, ax=axes[1, 0])
axes[1, 0].set_title('Likes Vs Duration')
axes[1, 0].set_xlabel('Duration_ms')
axes[1, 0].set_ylabel('Likes')

# Scatter plot for Comments vs Duration_ms
sns.scatterplot(x='Duration_ms', y='Comments', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Comments Vs Duration')
axes[1, 1].set_xlabel('Duration_ms')
axes[1, 1].set_ylabel('Comments')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
top10_artists = data.sort_values(by='Likes', ascending=False).head(10)

plt.figure(figsize=(6, 4))
sns.barplot(x='Views', y='Artist', data=top10_artists, palette='viridis')
plt.title('Views of the 10 Most Liked Artists')
plt.xlabel('Views')
plt.ylabel('Artists')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# Assuming 'data' is your DataFrame and it includes 'Artist', 'Likes', and 'Views'
top10_artists = data.sort_values(by='Likes', ascending=False).head(10)

# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create bar plot for Views
sns.barplot(x='Artist', y='Views', data=top10_artists, palette='viridis', ax=ax1, label='Views')

# Create a second y-axis for Likes
ax2 = ax1.twinx()
sns.lineplot(x='Artist', y='Likes', data=top10_artists, color='red', marker='o', ax=ax2, label='Likes')

# Set titles and labels
ax1.set_title('Views and Likes of the 10 Most Liked Artists')
ax1.set_xlabel('Artist')
ax1.set_ylabel('Views', color='black')
ax2.set_ylabel('Likes', color='red')

# Rotate x labels for better readability
plt.xticks(rotation=45, ha='right')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show plot
plt.tight_layout()
plt.show()

# %%
# Step 1: Aggregate likes and identify top 10 most liked channels
channel_likes = data.groupby('Channel')['Likes'].sum().reset_index()
top10_channels = channel_likes.sort_values(by='Likes', ascending=False).head(10)

# Step 2: Aggregate views for each channel
channel_views = data.groupby('Channel')['Views'].sum().reset_index()

# Merge likes and views data to get views for the top 10 most liked channels
top10_channels = top10_channels.merge(channel_views, on='Channel')

# Step 3: Plot views of the 10 most liked channels
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='Views', y='Channel', data=top10_channels, palette='viridis')

# Add labels for Likes
for index, row in top10_channels.iterrows():
    ax.text(row['Views'], index, f'{row["Likes"]}', color='black', ha='left', va='center')

plt.title('Views of the 10 Most Liked Channels')
plt.xlabel('Views')
plt.ylabel('Channel')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
new_df=data.groupby(['Album'])['Views','Likes'].mean()
top10_albums=new_df.sort_values(by='Likes',ascending=False)[:10]
top10_albums
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4436\1867183081.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                            Views         Likes
# Album
# See You Again (feat. Charlie Puth)  5.773798e+09  4.014765e+07
# BE                                  1.640946e+09  3.589258e+07
# MAP OF THE SOUL : PERSONA           1.634110e+09  2.758821e+07
# Gangnam Style (강남스타일)               4.679767e+09  2.639913e+07
# lovely (with Khalid)                1.721391e+09  2.442602e+07
# THE ALBUM                           1.182611e+09  2.429031e+07
# KILL THIS LOVE                      1.734794e+09  2.406157e+07
# My World 2.0                        2.905793e+09  2.321227e+07
# SQUARE UP                           2.012855e+09  2.257028e+07
# VIDA                                3.523481e+09  2.065381e+07

# %%
# Group by 'Album' and calculate the mean of 'Views' and 'Likes'
new_df = data.groupby('Album')[['Views', 'Likes']].sum().reset_index()

# Sort by 'Likes' and get the top 10 albums
top10_albums = new_df.sort_values(by='Likes', ascending=False).head(10)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot average views as a bar chart
sns.barplot(x='Album', y='Views', data=top10_albums, ax=ax1, palette='viridis', label='Total Views')
ax1.set_xlabel('Album')
ax1.set_ylabel('Total Views')
ax1.set_title('Top 10 Albums by Total Likes and Total Views')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

# Create a second y-axis for the line plot
ax2 = ax1.twinx()
sns.lineplot(x='Album', y='Likes', data=top10_albums, ax=ax2, color='r', marker='o', label='Total Likes')
ax2.set_ylabel('Total Likes')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()
